# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Valentin Blehaut**
#
# Intergalactic Real Estate Developer

# %% [markdown]
# *Data science is a must-have tool for any aspiring intergalactic real estate agent. Imagine not being able to know which planet people are headed to? How in the worlds are you supposed to know where to develop next next?*

# %% [markdown]
# ### Below I shall solve a complex mathematical problem. Behold:

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# | This | is   |
# |------|------|
# |   a  | table|
#
# - This is
# - A bulleted
# - List
#
# And for my final trick, a picture of ~~Fry~~ me:
#
# ![uyhhb.jpeg](attachment:543b1c2e-f3fc-4489-aa95-36fa52cac3fc.jpeg)
